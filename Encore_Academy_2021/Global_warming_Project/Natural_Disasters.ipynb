# %%
# 박상우

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data_Source_URL:  "https://www.kaggle.com/jnegrini/emdat19002021"
    
"The credit for creating and maintaining the Database is for the Centre for Research on the Epidemiology of Disasters - CRED and the School of Public Health from the Université catholique de Louvain."

'“EM-DAT, CRED / UCLouvain, Brussels, Belgium – www.emdat.be (D. Guha-Sapir)”'
# Out:
# '“EM-DAT, CRED / UCLouvain, Brussels, Belgium – www.emdat.be (D. Guha-Sapir)”'

# %%
df = pd.read_csv('Natural_Disasters/EMDAT_1900-2021_NatDis.csv')
df
# Out:
#               Dis No  Year   Seq Disaster Group Disaster Subgroup  \
# 0      1900-9002-CPV  1900  9002        Natural    Climatological
# 1      1900-9001-IND  1900  9001        Natural    Climatological
# 2      1902-0012-GTM  1902    12        Natural       Geophysical
# 3      1902-0003-GTM  1902     3        Natural       Geophysical
# 4      1902-0010-GTM  1902    10        Natural       Geophysical
# ...              ...   ...   ...            ...               ...
# 15822  2020-0031-ZMB  2020    31        Natural      Hydrological
# 15823  2020-0110-ZMB  2020   110        Natural      Hydrological
# 15824  2021-0036-ZWE  2021    36        Natural    Meteorological
# 15825  2020-0131-TLS  2020   131        Natural      Hydrological
# 15826  2020-0362-SSD  2020   362        Natural      Hydrological
#
#            Disaster Type  Disaster Subtype Disaster Subsubtype  \
# 0                Drought           Drought                 NaN
# 1                Drought           Drought                 NaN
# 2             Earthquake   Ground movement                 NaN
# 3      Volcanic activity          Ash fall                 NaN
# 4      Volcanic activity          Ash fall                 NaN
# ...                  ...               ...                 ...
# 15822              Flood               NaN                 NaN
# 15823              Flood               NaN                 NaN
# 15824              Storm  Tropical cyclone                 NaN
# 15825              Flood    Riverine flood                 NaN
# 15826              Flood               NaN                 NaN
#
#                       Event Name Entry Criteria  ... End Day Total Deaths  \
# 0                            NaN            NaN  ...     NaN      11000.0
# 1                            NaN            NaN  ...     NaN    1250000.0
# 2                            NaN           Kill  ...    18.0       2000.0
# 3                    Santa Maria           Kill  ...     8.0       1000.0
# 4                    Santa Maria           Kill  ...    24.0       6000.0
# ...                          ...            ...  ...     ...          ...
# 15822                        NaN       Affected  ...     NaN          NaN
# 15823                        NaN       Affected  ...    26.0          NaN
# 15824  Tropical cyclone 'Eloise'           Kill  ...    23.0          3.0
# 15825                        NaN       Affected  ...    13.0          3.0
# 15826                        NaN       Affected  ...     NaN          NaN
#
#       No Injured No Affected No Homeless Total Affected  \
# 0            NaN         NaN         NaN            NaN
# 1            NaN         NaN         NaN            NaN
# 2            NaN         NaN         NaN            NaN
# 3            NaN         NaN         NaN            NaN
# 4            NaN         NaN         NaN            NaN
# ...          ...         ...         ...            ...
# 15822        NaN      1500.0         NaN         1500.0
# 15823        NaN    700000.0         NaN       700000.0
# 15824        NaN      1745.0         NaN         1745.0
# 15825        7.0      9124.0         NaN         9131.0
# 15826        NaN   1042000.0         NaN      1042000.0
#
#       Reconstruction Costs ('000 US$) Insured Damages ('000 US$)  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# ...                               ...                        ...
# 15822                             NaN                        NaN
# 15823                             NaN                        NaN
# 15824                             NaN                        NaN
# 15825                             NaN                        NaN
# 15826                             NaN                        NaN
#
#       Total Damages ('000 US$)       CPI
# 0                          NaN  3.261389
# 1                          NaN  3.261389
# 2                      25000.0  3.391845
# 3                          NaN  3.391845
# 4                          NaN  3.391845
# ...                        ...       ...
# 15822                      NaN       NaN
# 15823                      NaN       NaN
# 15824                      NaN       NaN
# 15825                  20000.0       NaN
# 15826                      NaN       NaN
#
# [15827 rows x 43 columns]

# %%
#1900-2020년까지 총 피해액
df["Total Damages ('000 US$)"].describe()
# Out:
# count    5.166000e+03
# mean     7.174439e+05
# std      4.733454e+06
# min      2.000000e+00
# 25%      8.000000e+03
# 50%      6.000000e+04
# 75%      3.150000e+05
# max      2.100000e+08
# Name: Total Damages ('000 US$), dtype: float64

# %%
#인덱스 = 년도
df.index = df["Year"]

# %%
 year = df.index > 1944

# %%
df2 = df[year] #필요한 연도로 자르기
df2
# Out:
#              Dis No  Year  Seq Disaster Group Disaster Subgroup Disaster Type  \
# Year
# 1945  1945-0009-BEL  1945    9        Natural        Biological      Epidemic
# 1945  1945-0004-BHS  1945    4        Natural    Meteorological         Storm
# 1945  1945-0005-IND  1945    5        Natural    Meteorological         Storm
# 1946  1946-0013-CHL  1946   13        Natural       Geophysical    Earthquake
# 1946  1946-0021-DOM  1946   21        Natural       Geophysical    Earthquake
# ...             ...   ...  ...            ...               ...           ...
# 2020  2020-0031-ZMB  2020   31        Natural      Hydrological         Flood
# 2020  2020-0110-ZMB  2020  110        Natural      Hydrological         Flood
# 2021  2021-0036-ZWE  2021   36        Natural    Meteorological         Storm
# 2020  2020-0131-TLS  2020  131        Natural      Hydrological         Flood
# 2020  2020-0362-SSD  2020  362        Natural      Hydrological         Flood
#
#       Disaster Subtype Disaster Subsubtype                 Event Name  \
# Year
# 1945     Viral disease                 NaN                      Polio
# 1945  Tropical cyclone                 NaN                        NaN
# 1945  Tropical cyclone                 NaN                        NaN
# 1946   Ground movement                 NaN                        NaN
# 1946   Ground movement                 NaN                        NaN
# ...                ...                 ...                        ...
# 2020               NaN                 NaN                        NaN
# 2020               NaN                 NaN                        NaN
# 2021  Tropical cyclone                 NaN  Tropical cyclone 'Eloise'
# 2020    Riverine flood                 NaN                        NaN
# 2020               NaN                 NaN                        NaN
#
#      Entry Criteria  ... End Day Total Deaths No Injured No Affected  \
# Year                 ...
# 1945         Affect  ...     NaN          NaN        NaN       104.0
# 1945           Kill  ...    14.0         22.0        NaN         NaN
# 1945           OFDA  ...    18.0          NaN        NaN         NaN
# 1946           OFDA  ...     2.0          2.0        NaN         NaN
# 1946           Kill  ...     4.0         73.0        NaN         NaN
# ...             ...  ...     ...          ...        ...         ...
# 2020       Affected  ...     NaN          NaN        NaN      1500.0
# 2020       Affected  ...    26.0          NaN        NaN    700000.0
# 2021           Kill  ...    23.0          3.0        NaN      1745.0
# 2020       Affected  ...    13.0          3.0        7.0      9124.0
# 2020       Affected  ...     NaN          NaN        NaN   1042000.0
#
#      No Homeless Total Affected Reconstruction Costs ('000 US$)  \
# Year
# 1945         NaN          104.0                             NaN
# 1945         NaN            NaN                             NaN
# 1945      2000.0         2000.0                             NaN
# 1946         NaN            NaN                             NaN
# 1946         NaN            NaN                             NaN
# ...          ...            ...                             ...
# 2020         NaN         1500.0                             NaN
# 2020         NaN       700000.0                             NaN
# 2021         NaN         1745.0                             NaN
# 2020         NaN         9131.0                             NaN
# 2020         NaN      1042000.0                             NaN
#
#      Insured Damages ('000 US$) Total Damages ('000 US$)       CPI
# Year
# 1945                        NaN                      NaN  7.057646
# 1945                        NaN                      NaN  7.057646
# 1945                        NaN                      NaN  7.057646
# 1946                        NaN                      NaN  7.644696
# 1946                        NaN                      NaN  7.644696
# ...                         ...                      ...       ...
# 2020                        NaN                      NaN       NaN
# 2020                        NaN                      NaN       NaN
# 2021                        NaN                      NaN       NaN
# 2020                        NaN                  20000.0       NaN
# 2020                        NaN                      NaN       NaN
#
# [15353 rows x 43 columns]

# %%
# 자연재해 종류별 분포율
df3 = df2["Disaster Type"].value_counts()
df3
# Out:
# Flood                    5364
# Storm                    4299
# Epidemic                 1472
# Earthquake               1312
# Landslide                 753
# Drought                   726
# Extreme temperature       599
# Wildfire                  448
# Volcanic activity         239
# Insect infestation         93
# Mass movement (dry)        44
# Fog                         1
# Impact                      1
# Animal accident             1
# Glacial lake outburst       1
# Name: Disaster Type, dtype: int64

# %%
df3.plot(kind = "pie", figsize = (20, 20), autopct = "%1.1f%%", subplots=True, labeldistance=None, legend=True, fontsize=30)
plt.title("Natural Disasters 1945-2021")
# Out:
# Text(0.5, 1.0, 'Natural Disasters 1945-2021')

# %%
# 연도별 자연재해 발생 횟수
years_of_disasters = df2["Year"].value_counts()
years_of_disasters
# Out:
# 2002    532
# 2000    523
# 2005    498
# 2007    449
# 2001    447
#        ...
# 1958     24
# 1949     21
# 1946     17
# 1945     17
# 1947     14
# Name: Year, Length: 77, dtype: int64

# %%
#연 평균 재해 횟수
years_of_disasters.mean()
# Out:
# 199.3896103896104

# %%
sorted_years_of_disasters = years_of_disasters.sort_index(level=1, ascending=False)
sorted_years_of_disasters
# Out:
# 2021     27
# 2020    397
# 2019    443
# 2018    336
# 2017    367
#        ...
# 1949     21
# 1948     25
# 1947     14
# 1946     17
# 1945     17
# Name: Year, Length: 77, dtype: int64

# %%
sorted_years_of_disasters.plot(kind="barh", figsize=(10,20), color="red")
plt.title("Natural Disasters 1945-2021")
plt.show()

# %%
# 연도별 사망자 수 집계
death_count_by_years = df2.groupby("Start Year")['Total Deaths'].sum()
death_count_by_years
# Out:
# Start Year
# 1945     11358.0
# 1946     35563.0
# 1947     17650.0
# 1948    120828.0
# 1949    123774.0
#           ...
# 2017     11895.0
# 2018     15217.0
# 2019     22452.0
# 2020     15316.0
# 2021       509.0
# Name: Total Deaths, Length: 77, dtype: float64

# %%
death_count_by_years.plot(kind="line", figsize=(10,5), color="Green")
plt.title("Casulities of the Natural Disasters 1945-2021")
plt.show()

# %%
sns.lineplot(data=df2, x="Start Year", y="Total Deaths")
# Out:
# <AxesSubplot:xlabel='Start Year', ylabel='Total Deaths'>

# %%
#대륙 별 발생 건수
df6 = df2["Continent"]
df6
# Out:
# Year
# 1945      Europe
# 1945    Americas
# 1945        Asia
# 1946    Americas
# 1946    Americas
#           ...
# 2020      Africa
# 2020      Africa
# 2021      Africa
# 2020        Asia
# 2020      Africa
# Name: Continent, Length: 15353, dtype: object

# %%
df7 = df6.value_counts()
df7
# Out:
# Asia        6155
# Americas    3740
# Africa      2863
# Europe      1903
# Oceania      692
# Name: Continent, dtype: int64

# %%
df7.plot(kind="bar", figsize=(10,5), color="Yellow")
plt.title("Natural Disasters 1945-2021 (In terms of continents)")
plt.show()

# %%
# 대륙별 사망자
df8 = df2.groupby("Continent")['Total Deaths'].sum()
df8
# Out:
# Continent
# Africa       984590.0
# Americas     620353.0
# Asia        5907753.0
# Europe       340934.0
# Oceania       14798.0
# Name: Total Deaths, dtype: float64

# %%
df8.plot(kind="bar", figsize=(10,5), color="Orange")
plt.title("Natural Disasters 1945-2021 (In terms of continents)")
plt.show()

# %%
#자연재해 TOP5
df9 = df2["Country"].value_counts()[:5]
df9 #Asia에서 벌어지는 대부분의 자연재해는 '중국'에서 발생한다는 것을 알 수 있다.
# Out:
# United States of America (the)    1016
# China                              924
# India                              718
# Philippines (the)                  645
# Indonesia                          542
# Name: Country, dtype: int64

# %%
df9.plot(kind="barh", figsize=(10,5), color="red")
plt.title("Top5 countries of the Natural Disasters 1945-2021")
plt.show()
