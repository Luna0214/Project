# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DataSet Source: https://www.kaggle.com/unitednations/international-greenhouse-gas-emissions

# %%
# 데이터 적재
df_green_gas = pd.read_csv('greenhouse_gas_data.csv')
df_green_gas
# Out:
#                country_or_area  year          value  \
# 0                    Australia  2014  393126.946994
# 1                    Australia  2013  396913.936530
# 2                    Australia  2012  406462.847704
# 3                    Australia  2011  403705.528314
# 4                    Australia  2010  406200.993184
# ...                        ...   ...            ...
# 8401  United States of America  1994     593.222570
# 8402  United States of America  1993     586.939752
# 8403  United States of America  1992     574.414624
# 8404  United States of America  1991     566.900968
# 8405  United States of America  1990     293.205663
#
#                                                category
# 0     carbon_dioxide_co2_emissions_without_land_use_...
# 1     carbon_dioxide_co2_emissions_without_land_use_...
# 2     carbon_dioxide_co2_emissions_without_land_use_...
# 3     carbon_dioxide_co2_emissions_without_land_use_...
# 4     carbon_dioxide_co2_emissions_without_land_use_...
# ...                                                 ...
# 8401  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8402  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8403  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8404  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8405  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
#
# [8406 rows x 4 columns]

# %%
df_green_gas.describe()
# Out:
#               year         value
# count  8406.000000  8.406000e+03
# mean   2002.188437  2.055472e+05
# std       7.151605  8.041504e+05
# min    1990.000000  1.103750e-06
# 25%    1996.000000  2.976980e+02
# 50%    2002.000000  7.840318e+03
# 75%    2008.000000  6.589885e+04
# max    2014.000000  7.422208e+06

# %%
#### 데이터 탐색

# %%
### 이건 가스 종류별로 분류하고 연도로 분류

# %%
gas_list = df_green_gas['category'].unique()
gas_list
# Out:
# array(['carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent',
#        'greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent',
#        'methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent',
#        'nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent',
#        'sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent',
#        'unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent'],
#       dtype=object)

# %%
#### 데이터 변형

# %%
df_carbon = df_green_gas.loc[ ( df_green_gas['category'] == 'carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent' ), : ]
df_carbon
#carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent 만 분류
# Out:
#                country_or_area  year         value  \
# 0                    Australia  2014  3.931269e+05
# 1                    Australia  2013  3.969139e+05
# 2                    Australia  2012  4.064628e+05
# 3                    Australia  2011  4.037055e+05
# 4                    Australia  2010  4.062010e+05
# ...                        ...   ...           ...
# 1069  United States of America  1994  5.377492e+06
# 1070  United States of America  1993  5.284759e+06
# 1071  United States of America  1992  5.170274e+06
# 1072  United States of America  1991  5.064880e+06
# 1073  United States of America  1990  5.115095e+06
#
#                                                category
# 0     carbon_dioxide_co2_emissions_without_land_use_...
# 1     carbon_dioxide_co2_emissions_without_land_use_...
# 2     carbon_dioxide_co2_emissions_without_land_use_...
# 3     carbon_dioxide_co2_emissions_without_land_use_...
# 4     carbon_dioxide_co2_emissions_without_land_use_...
# ...                                                 ...
# 1069  carbon_dioxide_co2_emissions_without_land_use_...
# 1070  carbon_dioxide_co2_emissions_without_land_use_...
# 1071  carbon_dioxide_co2_emissions_without_land_use_...
# 1072  carbon_dioxide_co2_emissions_without_land_use_...
# 1073  carbon_dioxide_co2_emissions_without_land_use_...
#
# [1074 rows x 4 columns]

# %%
df_gas_includ = df_green_gas.loc[ ( df_green_gas['category'] == 'greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent' ), : ]
df_gas_includ
#가스 종류별로 분류
# Out:
#                country_or_area  year         value  \
# 1074                 Australia  2014  5.223971e+05
# 1075                 Australia  2013  5.268827e+05
# 1076                 Australia  2012  5.373776e+05
# 1077                 Australia  2011  5.340898e+05
# 1078                 Australia  2010  5.339174e+05
# ...                        ...   ...           ...
# 2018  United States of America  1994  6.650297e+06
# 2019  United States of America  1993  6.566416e+06
# 2020  United States of America  1992  6.448677e+06
# 2021  United States of America  1991  6.330938e+06
# 2022  United States of America  1990  6.397144e+06
#
#                                                category
# 1074  greenhouse_gas_ghgs_emissions_including_indire...
# 1075  greenhouse_gas_ghgs_emissions_including_indire...
# 1076  greenhouse_gas_ghgs_emissions_including_indire...
# 1077  greenhouse_gas_ghgs_emissions_including_indire...
# 1078  greenhouse_gas_ghgs_emissions_including_indire...
# ...                                                 ...
# 2018  greenhouse_gas_ghgs_emissions_including_indire...
# 2019  greenhouse_gas_ghgs_emissions_including_indire...
# 2020  greenhouse_gas_ghgs_emissions_including_indire...
# 2021  greenhouse_gas_ghgs_emissions_including_indire...
# 2022  greenhouse_gas_ghgs_emissions_including_indire...
#
# [949 rows x 4 columns]

# %%
df_gas_out = df_green_gas.loc[ ( df_green_gas['category'] == 'greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent' ), : ]
df_gas_out
#가스 종류별로 분류
# Out:
#                country_or_area  year         value  \
# 2023                 Australia  2014  5.223971e+05
# 2024                 Australia  2013  5.268827e+05
# 2025                 Australia  2012  5.373776e+05
# 2026                 Australia  2011  5.340898e+05
# 2027                 Australia  2010  5.339174e+05
# ...                        ...   ...           ...
# 3092  United States of America  1994  6.650297e+06
# 3093  United States of America  1993  6.566416e+06
# 3094  United States of America  1992  6.448677e+06
# 3095  United States of America  1991  6.330938e+06
# 3096  United States of America  1990  6.397144e+06
#
#                                                category
# 2023  greenhouse_gas_ghgs_emissions_without_land_use...
# 2024  greenhouse_gas_ghgs_emissions_without_land_use...
# 2025  greenhouse_gas_ghgs_emissions_without_land_use...
# 2026  greenhouse_gas_ghgs_emissions_without_land_use...
# 2027  greenhouse_gas_ghgs_emissions_without_land_use...
# ...                                                 ...
# 3092  greenhouse_gas_ghgs_emissions_without_land_use...
# 3093  greenhouse_gas_ghgs_emissions_without_land_use...
# 3094  greenhouse_gas_ghgs_emissions_without_land_use...
# 3095  greenhouse_gas_ghgs_emissions_without_land_use...
# 3096  greenhouse_gas_ghgs_emissions_without_land_use...
#
# [1074 rows x 4 columns]

# %%
df_HFCs = df_green_gas.loc[ ( df_green_gas['category'] == 'hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent' ), : ]
df_HFCs
#가스 종류별로 분류
# Out:
#                country_or_area  year         value  \
# 3097                 Australia  2014  10787.350138
# 3098                 Australia  2013  10034.127624
# 3099                 Australia  2012   9353.066412
# 3100                 Australia  2011   8837.850581
# 3101                 Australia  2010   8166.067244
# ...                        ...   ...           ...
# 4067  United States of America  1994  53246.654974
# 4068  United States of America  1993  47500.262267
# 4069  United States of America  1992  47427.662176
# 4070  United States of America  1991  41618.413588
# 4071  United States of America  1990  46288.814184
#
#                                                category
# 3097  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 3098  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 3099  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 3100  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 3101  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# ...                                                 ...
# 4067  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 4068  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 4069  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 4070  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 4071  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
#
# [975 rows x 4 columns]

# %%
df_CH4 = df_green_gas.loc[ ( df_green_gas['category'] == 'methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent' ), : ]
df_CH4
#가스 종류별로 분류
# Out:
#                country_or_area  year          value  \
# 4072                 Australia  2014   98076.109401
# 4073                 Australia  2013   99857.204626
# 4074                 Australia  2012  100796.838744
# 4075                 Australia  2011  101085.537857
# 4076                 Australia  2010   99447.730159
# ...                        ...   ...            ...
# 5141  United States of America  1994  770450.426146
# 5142  United States of America  1993  764089.671267
# 5143  United States of America  1992  776869.789752
# 5144  United States of America  1991  777034.220915
# 5145  United States of America  1990  773854.896420
#
#                                                category
# 4072  methane_ch4_emissions_without_land_use_land_us...
# 4073  methane_ch4_emissions_without_land_use_land_us...
# 4074  methane_ch4_emissions_without_land_use_land_us...
# 4075  methane_ch4_emissions_without_land_use_land_us...
# 4076  methane_ch4_emissions_without_land_use_land_us...
# ...                                                 ...
# 5141  methane_ch4_emissions_without_land_use_land_us...
# 5142  methane_ch4_emissions_without_land_use_land_us...
# 5143  methane_ch4_emissions_without_land_use_land_us...
# 5144  methane_ch4_emissions_without_land_use_land_us...
# 5145  methane_ch4_emissions_without_land_use_land_us...
#
# [1074 rows x 4 columns]

# %%
df_NF3 = df_green_gas.loc[ ( df_green_gas['category'] == 'nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent' ), : ]
df_NF3
#가스 종류별로 분류
# Out:
#                country_or_area  year      value  \
# 5146                   Austria  2014  10.562520
# 5147                   Austria  2013   9.752400
# 5148                   Austria  2012   8.563880
# 5149                   Austria  2011   4.102200
# 5150                   Austria  2010   4.115960
# ...                        ...   ...        ...
# 5389  United States of America  1994  65.892167
# 5390  United States of America  1993  59.901970
# 5391  United States of America  1992  47.921576
# 5392  United States of America  1991  47.921576
# 5393  United States of America  1990  47.921576
#
#                                                category
# 5146  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5147  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5148  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5149  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5150  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# ...                                                 ...
# 5389  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5390  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5391  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5392  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5393  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
#
# [248 rows x 4 columns]

# %%
df_N2O = df_green_gas.loc[ ( df_green_gas['category'] == 'nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent' ), : ]
df_N2O
#가스 종류별로 분류
# Out:
#                country_or_area  year          value  \
# 5394                 Australia  2014   20084.542834
# 5395                 Australia  2013   19756.452647
# 5396                 Australia  2012   20342.383478
# 5397                 Australia  2011   20034.575149
# 5398                 Australia  2010   19698.298820
# ...                        ...   ...            ...
# 6463  United States of America  1994  402478.930460
# 6464  United States of America  1993  420503.190940
# 6465  United States of America  1992  404052.107073
# 6466  United States of America  1991  396113.656867
# 6467  United States of America  1990  406228.526626
#
#                                                category
# 5394  nitrous_oxide_n2o_emissions_without_land_use_l...
# 5395  nitrous_oxide_n2o_emissions_without_land_use_l...
# 5396  nitrous_oxide_n2o_emissions_without_land_use_l...
# 5397  nitrous_oxide_n2o_emissions_without_land_use_l...
# 5398  nitrous_oxide_n2o_emissions_without_land_use_l...
# ...                                                 ...
# 6463  nitrous_oxide_n2o_emissions_without_land_use_l...
# 6464  nitrous_oxide_n2o_emissions_without_land_use_l...
# 6465  nitrous_oxide_n2o_emissions_without_land_use_l...
# 6466  nitrous_oxide_n2o_emissions_without_land_use_l...
# 6467  nitrous_oxide_n2o_emissions_without_land_use_l...
#
# [1074 rows x 4 columns]

# %%
df_CF4 = df_green_gas.loc[ ( df_green_gas['category'] == 'perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent' ), : ]
df_CF4
#가스 종류별로 분류
# Out:
#                country_or_area  year         value  \
# 6468                 Australia  2014    192.535991
# 6469                 Australia  2013    192.001236
# 6470                 Australia  2012    294.882947
# 6471                 Australia  2011    301.304840
# 6472                 Australia  2010    283.315235
# ...                        ...   ...           ...
# 7294  United States of America  1994  17965.003964
# 7295  United States of America  1993  19484.617791
# 7296  United States of America  1992  19481.087044
# 7297  United States of America  1991  20912.457841
# 7298  United States of America  1990  24255.671543
#
#                                                category
# 6468  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 6469  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 6470  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 6471  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 6472  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# ...                                                 ...
# 7294  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 7295  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 7296  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 7297  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 7298  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
#
# [831 rows x 4 columns]

# %%
df_SF6 = df_green_gas.loc[ ( df_green_gas['category'] == 'sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent' ), : ]
df_SF6
#가스 종류별로 분류
# Out:
#                country_or_area  year         value  \
# 7299                 Australia  2014    129.605354
# 7300                 Australia  2013    128.944604
# 7301                 Australia  2012    127.552168
# 7302                 Australia  2011    125.001945
# 7303                 Australia  2010    121.031654
# ...                        ...   ...           ...
# 8326  United States of America  1994  28004.247351
# 8327  United States of America  1993  29432.652199
# 8328  United States of America  1992  29949.821295
# 8329  United States of America  1991  29764.563408
# 8330  United States of America  1990  31080.406159
#
#                                                category
# 7299  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 7300  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 7301  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 7302  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 7303  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# ...                                                 ...
# 8326  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8327  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8328  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8329  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8330  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
#
# [1032 rows x 4 columns]

# %%
df_unspecified_HFCs = df_green_gas.loc[ ( df_green_gas['category'] == 'unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent' ), : ]
df_unspecified_HFCs
#가스 종류별로 분류
# Out:
#                country_or_area  year       value  \
# 8331            European Union  2014  151.948998
# 8332            European Union  2013  193.404159
# 8333            European Union  2012  182.082665
# 8334            European Union  2011  176.677800
# 8335            European Union  2010  366.271910
# ...                        ...   ...         ...
# 8401  United States of America  1994  593.222570
# 8402  United States of America  1993  586.939752
# 8403  United States of America  1992  574.414624
# 8404  United States of America  1991  566.900968
# 8405  United States of America  1990  293.205663
#
#                                                category
# 8331  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8332  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8333  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8334  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8335  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# ...                                                 ...
# 8401  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8402  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8403  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8404  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8405  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
#
# [75 rows x 4 columns]

# %%
##데이터 탐색

# %%
df_carbon['value'].describe()
# Out:
# count    1.074000e+03
# mean     4.320488e+05
# std      1.059768e+06
# min      7.188190e+01
# 25%      2.437971e+04
# 50%      6.166444e+04
# 75%      3.355781e+05
# max      6.122747e+06
# Name: value, dtype: float64

# %%
df_gas_includ['value'].describe()
# Out:
# count    9.490000e+02
# mean     5.874106e+05
# std      1.391225e+06
# min      8.672830e+01
# 25%      5.023377e+04
# 50%      8.202159e+04
# 75%      4.421724e+05
# max      7.422208e+06
# Name: value, dtype: float64

# %%
df_gas_out['value'].describe()
# Out:
# count    1.074000e+03
# mean     5.448683e+05
# std      1.315580e+06
# min      8.672830e+01
# 25%      3.103084e+04
# 50%      8.039956e+04
# 75%      4.337441e+05
# max      7.422208e+06
# Name: value, dtype: float64

# %%
df_HFCs['value'].describe()
# Out:
# count       975.000000
# mean       7459.376347
# std       20689.859710
# min           0.000072
# 25%          94.093743
# 50%         747.113470
# 75%        4687.462634
# max      157237.344889
# Name: value, dtype: float64

# %%
df_CH4['value'].describe()
# Out:
# count      1074.000000
# mean      73302.713114
# std      175440.581069
# min           0.849257
# 25%        4371.571186
# 50%       11911.258116
# 75%       48126.335763
# max      942383.462118
# Name: value, dtype: float64

# %%
df_NF3['value'].describe()
# Out:
# count     248.000000
# mean      113.467226
# std       267.025197
# min         0.055900
# 25%         1.262596
# 50%        20.977292
# 75%        62.548292
# max      1561.299969
# Name: value, dtype: float64

# %%
df_N2O['value'].describe()
# Out:
# count      1074.000000
# mean      29922.486723
# std       76097.510577
# min           1.645551
# 25%        2583.225829
# 50%        6634.584903
# 75%       20315.661481
# max      433872.649154
# Name: value, dtype: float64

# %%
df_CF4['value'].describe()
# Out:
# count      831.000000
# mean      1823.313419
# std       3864.704285
# min          0.000001
# 25%         41.595919
# 50%        212.887732
# 75%       1656.134687
# max      25369.662019
# Name: value, dtype: float64

# %%
df_SF6['value'].describe()
# Out:
# count     1032.000000
# mean      1204.614834
# std       3675.280918
# min          0.000456
# 25%          5.109643
# 50%         52.634749
# 75%        442.487524
# max      31080.406159
# Name: value, dtype: float64

# %%
df_unspecified_HFCs['value'].describe()
# Out:
# count      75.000000
# mean     3264.532560
# std      2616.922348
# min       151.948998
# 25%       776.432194
# 50%      3904.524176
# 75%      5229.436475
# max      9449.891683
# Name: value, dtype: float64

# %%
df_unspecified_HFCs['year'].sort_values()
# Out:
# 8405    1990
# 8355    1990
# 8380    1990
# 8379    1991
# 8354    1991
#         ...
# 8332    2013
# 8357    2013
# 8356    2014
# 8381    2014
# 8331    2014
# Name: year, Length: 75, dtype: int64

# %%
df_unspecified_HFCs['value']
# Out:
# 8331    151.948998
# 8332    193.404159
# 8333    182.082665
# 8334    176.677800
# 8335    366.271910
#            ...
# 8401    593.222570
# 8402    586.939752
# 8403    574.414624
# 8404    566.900968
# 8405    293.205663
# Name: value, Length: 75, dtype: float64

# %% [markdown]
# ### GAS 당 배출 단위는 '킬로톤(KilloTons)'입니다.

# %%
# CO2 (지구온난화의 80%를 담당하고 있다)
df_carbon.info
# Out:
# <bound method DataFrame.info of                country_or_area  year         value  \
# 0                    Australia  2014  3.931269e+05
# 1                    Australia  2013  3.969139e+05
# 2                    Australia  2012  4.064628e+05
# 3                    Australia  2011  4.037055e+05
# 4                    Australia  2010  4.062010e+05
# ...                        ...   ...           ...
# 1069  United States of America  1994  5.377492e+06
# 1070  United States of America  1993  5.284759e+06
# 1071  United States of America  1992  5.170274e+06
# 1072  United States of America  1991  5.064880e+06
# 1073  United States of America  1990  5.115095e+06
#
#                                                category
# 0     carbon_dioxide_co2_emissions_without_land_use_...
# 1     carbon_dioxide_co2_emissions_without_land_use_...
# 2     carbon_dioxide_co2_emissions_without_land_use_...
# 3     carbon_dioxide_co2_emissions_without_land_use_...
# 4     carbon_dioxide_co2_emissions_without_land_use_...
# ...                                                 ...
# 1069  carbon_dioxide_co2_emissions_without_land_use_...
# 1070  carbon_dioxide_co2_emissions_without_land_use_...
# 1071  carbon_dioxide_co2_emissions_without_land_use_...
# 1072  carbon_dioxide_co2_emissions_without_land_use_...
# 1073  carbon_dioxide_co2_emissions_without_land_use_...
#
# [1074 rows x 4 columns]>

# %%
df_carbon.describe()
# Out:
#               year         value
# count  1074.000000  1.074000e+03
# mean   2001.988827  4.320488e+05
# std       7.208509  1.059768e+06
# min    1990.000000  7.188190e+01
# 25%    1996.000000  2.437971e+04
# 50%    2002.000000  6.166444e+04
# 75%    2008.000000  3.355781e+05
# max    2014.000000  6.122747e+06

# %%
df_carbon_sum = df_carbon['value'].groupby(df_carbon['country_or_area']).sum()
sorted_df_carbon_sum = df_carbon_sum.sort_values()
head_sorted_df_carbon_sum = sorted_df_carbon_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_carbon_sum.plot(kind="bar", color="white" )
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_carbon_sum_year = df_carbon.groupby('year').sum().sort_index(ascending=False)
df_carbon_sum_year
# Out:
#              value
# year
# 2014  1.720950e+07
# 2013  1.758251e+07
# 2012  1.765477e+07
# 2011  1.791327e+07
# 2010  1.819953e+07
# 2009  1.758059e+07
# 2008  1.896770e+07
# 2007  1.944015e+07
# 2006  1.936924e+07
# 2005  1.935249e+07
# 2004  1.931086e+07
# 2003  1.913444e+07
# 2002  1.880365e+07
# 2001  1.877537e+07
# 2000  1.870867e+07
# 1999  1.843021e+07
# 1998  1.842393e+07
# 1997  1.846781e+07
# 1996  1.861941e+07
# 1995  1.825989e+07
# 1994  1.814589e+07
# 1993  1.833110e+07
# 1992  1.857177e+07
# 1991  1.918634e+07
# 1990  1.958134e+07

# %%
df_carbon_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>

# %%
# 자연흡수량은 제외한 순수 온실가스 배출량
df_gas_includ.info
# Out:
# <bound method DataFrame.info of                country_or_area  year         value  \
# 1074                 Australia  2014  5.223971e+05
# 1075                 Australia  2013  5.268827e+05
# 1076                 Australia  2012  5.373776e+05
# 1077                 Australia  2011  5.340898e+05
# 1078                 Australia  2010  5.339174e+05
# ...                        ...   ...           ...
# 2018  United States of America  1994  6.650297e+06
# 2019  United States of America  1993  6.566416e+06
# 2020  United States of America  1992  6.448677e+06
# 2021  United States of America  1991  6.330938e+06
# 2022  United States of America  1990  6.397144e+06
#
#                                                category
# 1074  greenhouse_gas_ghgs_emissions_including_indire...
# 1075  greenhouse_gas_ghgs_emissions_including_indire...
# 1076  greenhouse_gas_ghgs_emissions_including_indire...
# 1077  greenhouse_gas_ghgs_emissions_including_indire...
# 1078  greenhouse_gas_ghgs_emissions_including_indire...
# ...                                                 ...
# 2018  greenhouse_gas_ghgs_emissions_including_indire...
# 2019  greenhouse_gas_ghgs_emissions_including_indire...
# 2020  greenhouse_gas_ghgs_emissions_including_indire...
# 2021  greenhouse_gas_ghgs_emissions_including_indire...
# 2022  greenhouse_gas_ghgs_emissions_including_indire...
#
# [949 rows x 4 columns]>

# %%
df_gas_includ.describe()
# Out:
#               year         value
# count   949.000000  9.490000e+02
# mean   2001.987355  5.874106e+05
# std       7.208165  1.391225e+06
# min    1990.000000  8.672830e+01
# 25%    1996.000000  5.023377e+04
# 50%    2002.000000  8.202159e+04
# 75%    2008.000000  4.421724e+05
# max    2014.000000  7.422208e+06

# %%
df_gas_includ_sum = df_gas_includ['value'].groupby(df_gas_includ['country_or_area']).sum()
sorted_df_gas_includ_sum = df_gas_includ_sum.sort_values()
head_sorted_df_gas_includ_sum = sorted_df_gas_includ_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_gas_includ_sum.plot(kind="bar", color="white" )
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_gas_includ_sum_year = df_gas_includ.groupby('year').sum().sort_index(ascending=False)
df_gas_includ_sum_year
# Out:
#              value
# year
# 2014  2.090702e+07
# 2013  2.122217e+07
# 2012  2.125789e+07
# 2011  2.151672e+07
# 2010  2.175162e+07
# 2009  2.111136e+07
# 2008  2.249868e+07
# 2007  2.296387e+07
# 2006  2.287129e+07
# 2005  2.284798e+07
# 2004  2.285699e+07
# 2003  2.263871e+07
# 2002  2.232623e+07
# 2001  2.231868e+07
# 2000  2.230081e+07
# 1999  2.207214e+07
# 1998  2.223090e+07
# 1997  2.233209e+07
# 1996  2.253634e+07
# 1995  2.220771e+07
# 1994  2.206725e+07
# 1993  2.236234e+07
# 1992  2.270111e+07
# 1991  2.348952e+07
# 1990  2.406325e+07

# %%
df_gas_includ_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>

# %%
# 토지 범위별 숲의 온실가스 흡수량
df_gas_out.info
# Out:
# <bound method DataFrame.info of                country_or_area  year         value  \
# 2023                 Australia  2014  5.223971e+05
# 2024                 Australia  2013  5.268827e+05
# 2025                 Australia  2012  5.373776e+05
# 2026                 Australia  2011  5.340898e+05
# 2027                 Australia  2010  5.339174e+05
# ...                        ...   ...           ...
# 3092  United States of America  1994  6.650297e+06
# 3093  United States of America  1993  6.566416e+06
# 3094  United States of America  1992  6.448677e+06
# 3095  United States of America  1991  6.330938e+06
# 3096  United States of America  1990  6.397144e+06
#
#                                                category
# 2023  greenhouse_gas_ghgs_emissions_without_land_use...
# 2024  greenhouse_gas_ghgs_emissions_without_land_use...
# 2025  greenhouse_gas_ghgs_emissions_without_land_use...
# 2026  greenhouse_gas_ghgs_emissions_without_land_use...
# 2027  greenhouse_gas_ghgs_emissions_without_land_use...
# ...                                                 ...
# 3092  greenhouse_gas_ghgs_emissions_without_land_use...
# 3093  greenhouse_gas_ghgs_emissions_without_land_use...
# 3094  greenhouse_gas_ghgs_emissions_without_land_use...
# 3095  greenhouse_gas_ghgs_emissions_without_land_use...
# 3096  greenhouse_gas_ghgs_emissions_without_land_use...
#
# [1074 rows x 4 columns]>

# %%
df_gas_out.describe()
# Out:
#               year         value
# count  1074.000000  1.074000e+03
# mean   2001.988827  5.448683e+05
# std       7.208509  1.315580e+06
# min    1990.000000  8.672830e+01
# 25%    1996.000000  3.103084e+04
# 50%    2002.000000  8.039956e+04
# 75%    2008.000000  4.337441e+05
# max    2014.000000  7.422208e+06

# %%
df_gas_out_sum = df_gas_out['value'].groupby(df_gas_out['country_or_area']).sum()
sorted_df_gas_out_sum = df_gas_out_sum.sort_values()
head_sorted_df_gas_out_sum = sorted_df_gas_out_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_gas_out_sum.plot(kind="bar", color="white" )
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_gas_out_sum_year = df_gas_out.groupby('year').sum().sort_index(ascending=False)
df_gas_out_sum_year
# Out:
#              value
# year
# 2014  2.180341e+07
# 2013  2.216624e+07
# 2012  2.224357e+07
# 2011  2.249399e+07
# 2010  2.277291e+07
# 2009  2.213277e+07
# 2008  2.362539e+07
# 2007  2.413944e+07
# 2006  2.404608e+07
# 2005  2.403658e+07
# 2004  2.403138e+07
# 2003  2.380277e+07
# 2002  2.346562e+07
# 2001  2.347381e+07
# 2000  2.345340e+07
# 1999  2.320129e+07
# 1998  2.335742e+07
# 1997  2.347370e+07
# 1996  2.368839e+07
# 1995  2.332896e+07
# 1994  2.319549e+07
# 1993  2.348918e+07
# 1992  2.386266e+07
# 1991  2.466290e+07
# 1990  2.524116e+07

# %%
df_gas_out_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>

# %%
# 수소화불화탄소 (오존층 파괴의 원인)
df_HFCs.info
# Out:
# <bound method DataFrame.info of                country_or_area  year         value  \
# 3097                 Australia  2014  10787.350138
# 3098                 Australia  2013  10034.127624
# 3099                 Australia  2012   9353.066412
# 3100                 Australia  2011   8837.850581
# 3101                 Australia  2010   8166.067244
# ...                        ...   ...           ...
# 4067  United States of America  1994  53246.654974
# 4068  United States of America  1993  47500.262267
# 4069  United States of America  1992  47427.662176
# 4070  United States of America  1991  41618.413588
# 4071  United States of America  1990  46288.814184
#
#                                                category
# 3097  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 3098  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 3099  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 3100  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 3101  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# ...                                                 ...
# 4067  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 4068  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 4069  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 4070  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
# 4071  hydrofluorocarbons_hfcs_emissions_in_kilotonne...
#
# [975 rows x 4 columns]>

# %%
df_HFCs.describe()
# Out:
#               year          value
# count   975.000000     975.000000
# mean   2002.738462    7459.376347
# std       6.901203   20689.859710
# min    1990.000000       0.000072
# 25%    1997.000000      94.093743
# 50%    2003.000000     747.113470
# 75%    2009.000000    4687.462634
# max    2014.000000  157237.344889

# %%
df_HFCs_sum = df_HFCs['value'].groupby(df_HFCs['country_or_area']).sum()
sorted_df_HFCs_sum = df_HFCs_sum.sort_values()
head_sorted_df_HFCs_sum = sorted_df_HFCs_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_HFCs_sum.plot(kind="bar", color="white" )
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_HFCs_sum_year = df_HFCs.groupby('year').sum().sort_index(ascending=False)
df_HFCs_sum_year
# Out:
#               value
# year
# 2014  472861.182681
# 2013  453782.413295
# 2012  438664.262586
# 2011  420021.672825
# 2010  407806.417215
# 2009  374770.861530
# 2008  369473.436270
# 2007  345487.863264
# 2006  319144.056712
# 2005  305224.766580
# 2004  287956.088757
# 2003  269408.447065
# 2002  267568.389618
# 2001  261360.089635
# 2000  270848.528501
# 1999  260286.222581
# 1998  277584.396120
# 1997  251987.797276
# 1996  221610.540220
# 1995  201551.928561
# 1994  169206.245579
# 1993  154779.352272
# 1992  158714.187070
# 1991  153987.524302
# 1990  158805.268292

# %%
df_HFCs_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>

# %%
# 삼불화질소(오존에 550년간 머물며, CO2의 265배정도의 온실효과 발생시킴)
df_NF3.info
# Out:
# <bound method DataFrame.info of                country_or_area  year      value  \
# 5146                   Austria  2014  10.562520
# 5147                   Austria  2013   9.752400
# 5148                   Austria  2012   8.563880
# 5149                   Austria  2011   4.102200
# 5150                   Austria  2010   4.115960
# ...                        ...   ...        ...
# 5389  United States of America  1994  65.892167
# 5390  United States of America  1993  59.901970
# 5391  United States of America  1992  47.921576
# 5392  United States of America  1991  47.921576
# 5393  United States of America  1990  47.921576
#
#                                                category
# 5146  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5147  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5148  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5149  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5150  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# ...                                                 ...
# 5389  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5390  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5391  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5392  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
# 5393  nitrogen_trifluoride_nf3_emissions_in_kilotonn...
#
# [248 rows x 4 columns]>

# %%
df_NF3.describe()
# Out:
#               year        value
# count   248.000000   248.000000
# mean   2003.258065   113.467226
# std       7.148365   267.025197
# min    1990.000000     0.055900
# 25%    1997.000000     1.262596
# 50%    2004.000000    20.977292
# 75%    2010.000000    62.548292
# max    2014.000000  1561.299969

# %%
df_NF3_sum = df_NF3['value'].groupby(df_NF3['country_or_area']).sum()
sorted_df_NF3_sum = df_NF3_sum.sort_values()
head_sorted_df_NF3_sum = sorted_df_NF3_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_NF3_sum.plot(kind="bar", color="white" )
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_NF3_sum_year = df_NF3.groupby('year').sum().sort_index(ascending=False)
df_NF3_sum_year
# Out:
#             value
# year
# 2014  1470.387623
# 2013  2098.531341
# 2012  2074.333312
# 2011  2491.043659
# 2010  2179.128434
# 2009  1798.469370
# 2008  2066.992034
# 2007  2111.235547
# 2006  2077.017963
# 2005  2058.067999
# 2004  1183.698616
# 2003  1125.751795
# 2002  1096.071156
# 2001   589.061018
# 2000   623.614596
# 1999   525.960500
# 1998   526.322273
# 1997   477.569731
# 1996   425.819594
# 1995   373.294499
# 1994   207.910469
# 1993   162.946567
# 1992   135.858891
# 1991   132.098590
# 1990   128.686582

# %%
df_NF3_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>

# %%
# 아산화질소 (태양빛의 방사선을 흡수하여 온실효과 발생시킴)
df_N2O.info
# Out:
# <bound method DataFrame.info of                country_or_area  year          value  \
# 5394                 Australia  2014   20084.542834
# 5395                 Australia  2013   19756.452647
# 5396                 Australia  2012   20342.383478
# 5397                 Australia  2011   20034.575149
# 5398                 Australia  2010   19698.298820
# ...                        ...   ...            ...
# 6463  United States of America  1994  402478.930460
# 6464  United States of America  1993  420503.190940
# 6465  United States of America  1992  404052.107073
# 6466  United States of America  1991  396113.656867
# 6467  United States of America  1990  406228.526626
#
#                                                category
# 5394  nitrous_oxide_n2o_emissions_without_land_use_l...
# 5395  nitrous_oxide_n2o_emissions_without_land_use_l...
# 5396  nitrous_oxide_n2o_emissions_without_land_use_l...
# 5397  nitrous_oxide_n2o_emissions_without_land_use_l...
# 5398  nitrous_oxide_n2o_emissions_without_land_use_l...
# ...                                                 ...
# 6463  nitrous_oxide_n2o_emissions_without_land_use_l...
# 6464  nitrous_oxide_n2o_emissions_without_land_use_l...
# 6465  nitrous_oxide_n2o_emissions_without_land_use_l...
# 6466  nitrous_oxide_n2o_emissions_without_land_use_l...
# 6467  nitrous_oxide_n2o_emissions_without_land_use_l...
#
# [1074 rows x 4 columns]>

# %%
df_N2O.describe()
# Out:
#               year          value
# count  1074.000000    1074.000000
# mean   2001.988827   29922.486723
# std       7.208509   76097.510577
# min    1990.000000       1.645551
# 25%    1996.000000    2583.225829
# 50%    2002.000000    6634.584903
# 75%    2008.000000   20315.661481
# max    2014.000000  433872.649154

# %%
df_N2O_sum = df_N2O['value'].groupby(df_N2O['country_or_area']).sum()
sorted_df_N2O_sum = df_N2O_sum.sort_values()
head_sorted_df_N2O_sum = sorted_df_N2O_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_N2O_sum.plot(kind="bar", color="white" )
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_N2O_sum_year = df_N2O.groupby('year').sum().sort_index(ascending=False)
df_N2O_sum_year
# Out:
#              value
# year
# 2014  1.138729e+06
# 2013  1.135355e+06
# 2012  1.137160e+06
# 2011  1.145151e+06
# 2010  1.146164e+06
# 2009  1.149592e+06
# 2008  1.180266e+06
# 2007  1.221697e+06
# 2006  1.215054e+06
# 2005  1.222364e+06
# 2004  1.272584e+06
# 2003  1.230393e+06
# 2002  1.237225e+06
# 2001  1.257862e+06
# 2000  1.275261e+06
# 1999  1.279030e+06
# 1998  1.368096e+06
# 1997  1.393822e+06
# 1996  1.422483e+06
# 1995  1.407813e+06
# 1994  1.386909e+06
# 1993  1.417992e+06
# 1992  1.445219e+06
# 1991  1.494172e+06
# 1990  1.556360e+06

# %%
df_N2O_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>

# %%
# 플루오린화 탄소 (CO2의 1000~3000배정도의 온난화 잠재력을 보유)
df_CF4.info
# Out:
# <bound method DataFrame.info of                country_or_area  year         value  \
# 6468                 Australia  2014    192.535991
# 6469                 Australia  2013    192.001236
# 6470                 Australia  2012    294.882947
# 6471                 Australia  2011    301.304840
# 6472                 Australia  2010    283.315235
# ...                        ...   ...           ...
# 7294  United States of America  1994  17965.003964
# 7295  United States of America  1993  19484.617791
# 7296  United States of America  1992  19481.087044
# 7297  United States of America  1991  20912.457841
# 7298  United States of America  1990  24255.671543
#
#                                                category
# 6468  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 6469  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 6470  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 6471  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 6472  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# ...                                                 ...
# 7294  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 7295  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 7296  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 7297  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
# 7298  perfluorocarbons_pfcs_emissions_in_kilotonne_c...
#
# [831 rows x 4 columns]>

# %%
df_CF4.describe()
# Out:
#               year         value
# count   831.000000    831.000000
# mean   2002.317690   1823.313419
# std       7.139921   3864.704285
# min    1990.000000      0.000001
# 25%    1996.000000     41.595919
# 50%    2002.000000    212.887732
# 75%    2008.000000   1656.134687
# max    2014.000000  25369.662019

# %%
df_CF4_sum = df_CF4['value'].groupby(df_CF4['country_or_area']).sum()
sorted_df_CF4_sum = df_CF4_sum.sort_values()
head_sorted_df_CF4_sum = sorted_df_CF4_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_CF4_sum.plot(kind="bar", color="white" )
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_CF4_sum_year = df_CF4.groupby('year').sum().sort_index(ascending=False)
df_CF4_sum_year
# Out:
#               value
# year
# 2014   20703.192674
# 2013   22625.735778
# 2012   22697.502715
# 2011   24989.449691
# 2010   22833.788595
# 2009   21681.546304
# 2008   31652.057662
# 2007   37308.594329
# 2006   39409.621995
# 2005   43533.016342
# 2004   47071.086459
# 2003   51235.909683
# 2002   59074.715587
# 2001   56608.948442
# 2000   70053.965217
# 1999   76289.088275
# 1998   82658.659686
# 1997   89011.209971
# 1996   93336.429506
# 1995   94519.868027
# 1994   92297.409501
# 1993   95226.957024
# 1992   95962.473620
# 1991  109225.977985
# 1990  115166.245829

# %%
df_CF4_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>

# %%
# 육플루오린 황(100년 넘도록 오존에서 사라지지 않으며 CO2의 2,2000배 가량의 온난화 잠재력 보유)
df_SF6.info
# Out:
# <bound method DataFrame.info of                country_or_area  year         value  \
# 7299                 Australia  2014    129.605354
# 7300                 Australia  2013    128.944604
# 7301                 Australia  2012    127.552168
# 7302                 Australia  2011    125.001945
# 7303                 Australia  2010    121.031654
# ...                        ...   ...           ...
# 8326  United States of America  1994  28004.247351
# 8327  United States of America  1993  29432.652199
# 8328  United States of America  1992  29949.821295
# 8329  United States of America  1991  29764.563408
# 8330  United States of America  1990  31080.406159
#
#                                                category
# 7299  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 7300  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 7301  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 7302  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 7303  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# ...                                                 ...
# 8326  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8327  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8328  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8329  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8330  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
#
# [1032 rows x 4 columns]>

# %%
df_SF6.describe()
# Out:
#               year         value
# count  1032.000000   1032.000000
# mean   2002.337209   1204.614834
# std       7.070975   3675.280918
# min    1990.000000      0.000456
# 25%    1996.000000      5.109643
# 50%    2002.000000     52.634749
# 75%    2008.000000    442.487524
# max    2014.000000  31080.406159

# %%
df_SF6_sum = df_SF6['value'].groupby(df_SF6['country_or_area']).sum()
sorted_df_SF6_sum = df_SF6_sum.sort_values()
head_sorted_df_SF6_sum = sorted_df_SF6_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_SF6_sum.plot(kind="bar", color="white" )
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_SF6_sum_year = df_SF6.groupby('year').sum().sort_index(ascending=False)
df_SF6_sum_year
# Out:
#              value
# year
# 2014  23315.705903
# 2013  27551.190682
# 2012  29460.918449
# 2011  26868.498081
# 2010  26936.872977
# 2009  26608.209179
# 2008  30584.147232
# 2007  33552.057532
# 2006  37263.376096
# 2005  39146.761709
# 2004  40934.051152
# 2003  42211.582913
# 2002  43980.118084
# 2001  47396.492659
# 2000  51112.989816
# 1999  55982.891988
# 1998  65054.962237
# 1997  70281.231049
# 1996  77197.881972
# 1995  77183.821444
# 1994  75097.663520
# 1993  74717.085970
# 1992  74127.689943
# 1991  73987.625004
# 1990  72608.683052

# %%
df_SF6_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>

# %%
# 메탄가스 (오존에서 20년동안 머물며, CO2의 20배정도의 온실효과를 발생시킴)
df_CH4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1074 entries, 4072 to 5145
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country_or_area  1074 non-null   object
#  1   year             1074 non-null   int64
#  2   value            1074 non-null   float64
#  3   category         1074 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 42.0+ KB

# %%
df_CH4.describe()
# Out:
#               year          value
# count  1074.000000    1074.000000
# mean   2001.988827   73302.713114
# std       7.208509  175440.581069
# min    1990.000000       0.849257
# 25%    1996.000000    4371.571186
# 50%    2002.000000   11911.258116
# 75%    2008.000000   48126.335763
# max    2014.000000  942383.462118

# %%
df_CH4_sum = df_CH4['value'].groupby(df_CH4['country_or_area']).sum()
sorted_df_CH4_sum = df_CH4_sum.sort_values()
head_sorted_df_CH4_sum = sorted_df_CH4_sum.head()

# %%
plt.style.use("dark_background")
head_sorted_df_CH4_sum.plot(kind="bar", color="white" ) #CH4 발생순위 TOP5
# Out:
# <AxesSubplot:xlabel='country_or_area'>

# %%
df_CH4_sum_year = df_CH4.groupby('year').sum().sort_index(ascending=False)
df_CH4_sum_year
# Out:
#              value
# year
# 2014  2.927076e+06
# 2013  2.932934e+06
# 2012  2.949793e+06
# 2011  2.952670e+06
# 2010  2.958963e+06
# 2009  2.968152e+06
# 2008  3.035082e+06
# 2007  3.051411e+06
# 2006  3.056150e+06
# 2005  3.064061e+06
# 2004  3.063474e+06
# 2003  3.066742e+06
# 2002  3.044598e+06
# 2001  3.066744e+06
# 2000  3.068301e+06
# 1999  3.086477e+06
# 1998  3.126880e+06
# 1997  3.187989e+06
# 1996  3.242040e+06
# 1995  3.274319e+06
# 1994  3.314308e+06
# 1993  3.404186e+06
# 1992  3.505710e+06
# 1991  3.634010e+06
# 1990  3.745046e+06

# %%
df_CH4_sum_year.plot(kind="barh", figsize=(10,10), color="white")
# Out:
# <AxesSubplot:ylabel='year'>
